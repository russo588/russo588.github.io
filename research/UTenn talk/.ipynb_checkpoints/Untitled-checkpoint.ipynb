# %% [markdown]
# # This is a mark down slide

# %% [markdown]
# Here is a new slide

# %% [markdown]
# Here is a fragment

# %%
import matplotlib.pyplot as plt
import numpy as np
time = np.arange(0,1,0.1)
X = [t**2 for t in time]
plt.plot(time, X)

# %% [markdown]
# ![pic.png](attachment:pic.png)

# %% [markdown]
# <div style="background-image: url(Marquette_colloquium/pic.png); background-repeat: no-repeat; background-size: contain; height: auto; width: 100%; ">
#  this is
# some
#
# text on top of the background
#
# image
# </div>

# %% [markdown]
# <div style="background-image: url(Marquette_colloquium/pic.png); background-repeat: no-repeat; background-size: contain; height: auto; width: 100%; ">
#  this is
# some
#
# text on top of the background
#
# image
# </div>
